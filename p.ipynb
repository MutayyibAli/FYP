# %%
from data_preprocessing.preprocessor import Preprocessor

# %%
p = Preprocessor()
p.run()
p.collect_spacings(p.pt_ids)
# Out:
# ['00000',
#  '00002',
#  '00003',
#  '00005',
#  '00006',
#  '00008',
#  '00009',
#  '00011',
#  '00012',
#  '00014',
#  '00016',
#  '00017',
#  '00018',
#  '00019',
#  '00020',
#  '00021',
#  '00022',
#  '00024',
#  '00025',
#  '00026',
#  '00028',
#  '00030',
#  '00031',
#  '00032',
#  '00033',
#  '00035',
#  '00036',
#  '00043',
#  '00044',
#  '00045',
#  '00046',
#  '00048',
#  '00049',
#  '00051',
#  '00052',
#  '00053',
#  '00054',
#  '00056',
#  '00058',
#  '00059',
#  '00060',
#  '00061',
#  '00062',
#  '00063',
#  '00064',
#  '00066',
#  '00068',
#  '00070',
#  '00071',
#  '00072',
#  '00074',
#  '00077',
#  '00078',
#  '00081',
#  '00084',
#  '00085',
#  '00087',
#  '00088',
#  '00089',
#  '00090',
#  '00094',
#  '00095',
#  '00096',
#  '00097',
#  '00098',
#  '00099',
#  '00100',
#  '00101',
#  '00102',
#  '00103',
#  '00104',
#  '00105',
#  '00106',
#  '00107',
#  '00108',
#  '00109',
#  '00110',
#  '00111',
#  '00112',
#  '00113',
#  '00115',
#  '00116',
#  '00117',
# ...

# %%
import nibabel

image = nibabel.load(p.data_path + "/BraTS2021_00000/BraTS2021_00000_t1.nii.gz")

print(image.header["pixdim"][1:4].tolist())
